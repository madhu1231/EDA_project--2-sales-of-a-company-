# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales=pd.read_csv('Sales.csv')

# %%
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sales.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
sales.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
sales.sample(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4571    4572  US-2016-152128  25/05/2016  27/05/2016    Second Class
# 9344    9345  CA-2018-109085  17/02/2018  20/02/2018     First Class
# 9024    9025  CA-2017-102127  26/06/2017  02/07/2017  Standard Class
# 4778    4779  CA-2018-132346  07/11/2018  11/11/2018  Standard Class
# 3356    3357  US-2015-150434  19/07/2015  24/07/2015  Standard Class
# 6693    6694  CA-2018-144225  30/09/2018  02/10/2018    Second Class
# 5152    5153  US-2015-121566  30/06/2015  06/07/2015  Standard Class
# 6085    6086  US-2017-132577  22/11/2017  27/11/2017  Standard Class
# 127      128  US-2018-107272  05/11/2018  12/11/2018  Standard Class
# 3331    3332  CA-2018-122595  14/12/2018  20/12/2018  Standard Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 4571    NM-18445        Nathan Mautz  Home Office  United States
# 9344    CK-12325  Christine Kargatis  Home Office  United States
# ...

# %%
sales.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
sales[sales.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales]
# Index: []

# %%
sales.drop_duplicates(inplace=True)

# %%
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sales.sort_values('Order Date',ascending=False)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2821    2822  CA-2017-100202  31/12/2017  05/01/2018  Standard Class
# 4612    4613  US-2017-165953  31/12/2017  06/01/2018  Standard Class
# 1152    1153  CA-2017-160395  31/12/2017  06/01/2018  Standard Class
# 1153    1154  CA-2017-160395  31/12/2017  06/01/2018  Standard Class
# 5738    5739  CA-2017-156139  31/12/2017  06/01/2018  Standard Class
# ...      ...             ...         ...         ...             ...
# 8074    8075  CA-2018-151750  01/01/2018  05/01/2018  Standard Class
# 8073    8074  CA-2018-151750  01/01/2018  05/01/2018  Standard Class
# 8075    8076  CA-2018-151750  01/01/2018  05/01/2018  Standard Class
# 848      849  CA-2018-107503  01/01/2018  06/01/2018  Standard Class
# 6682    6683  CA-2018-154466  01/01/2018  02/01/2018     First Class
#
#      Customer ID    Customer Name      Segment        Country           City  \
# ...

# %%
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
s1=sales['Order Date'].str.split('/',expand=True)

# %%
s1
# Out:
#        0   1     2
# 0     08  11  2017
# 1     08  11  2017
# 2     12  06  2017
# 3     11  10  2016
# 4     11  10  2016
# ...   ..  ..   ...
# 9795  21  05  2017
# 9796  12  01  2016
# 9797  12  01  2016
# 9798  12  01  2016
# 9799  12  01  2016
#
# [9800 rows x 3 columns]

# %%
sales[['Order date','Order month','Order year']]=s1

# %%
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
s1=sales['Ship Date'].str.split('/',expand=True)

# %%
s1
# Out:
#        0   1     2
# 0     11  11  2017
# 1     11  11  2017
# 2     16  06  2017
# 3     18  10  2016
# 4     18  10  2016
# ...   ..  ..   ...
# 9795  28  05  2017
# 9796  17  01  2016
# 9797  17  01  2016
# 9798  17  01  2016
# 9799  17  01  2016
#
# [9800 rows x 3 columns]

# %%
sales[['ship date','ship month','ship year']]=s1

# %%
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sales.drop(['Row ID','Order Date','Ship Date'],axis=1,inplace=True)

# %%
sales
# Out:
#             Order ID       Ship Mode Customer ID     Customer Name    Segment  \
# 0     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 1     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 2     CA-2017-138688    Second Class    DV-13045   Darrin Van Huff  Corporate
# 3     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# 4     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# ...              ...             ...         ...               ...        ...
# 9795  CA-2017-125920  Standard Class    SH-19975     Sally Hughsby  Corporate
# 9796  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9797  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9798  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9799  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
#
# ...

# %%
sales['Order date'].nunique()
# Out:
# 31

# %%
sales['Postal Code'].nunique()
# Out:
# 626

# %%
sales['Region'].nunique()
# Out:
# 4

# %%
sales['Category'].nunique()
# Out:
# 3

# %%
sales['Sub-Category'].nunique()
# Out:
# 17

# %%
sales['Order date'].nunique()
# Out:
# 31

# %%
sales[['Postal Code','Region']]
# Out:
#       Postal Code   Region
# 0         42420.0    South
# 1         42420.0    South
# 2         90036.0     West
# 3         33311.0    South
# 4         33311.0    South
# ...           ...      ...
# 9795      60610.0  Central
# 9796      43615.0     East
# 9797      43615.0     East
# 9798      43615.0     East
# 9799      43615.0     East
#
# [9800 rows x 2 columns]

# %%
sales['Postal Code'].mean()
# Out:
# 55273.322402696904

# %%
sales.isnull().sum()
# Out:
# Order ID          0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Order date        0
# Order month       0
# Order year        0
# ship date         0
# ship month        0
# ship year         0
# dtype: int64

# %%
sales['Postal Code'].fillna(method='ffill',inplace=True)

# %%
sales.isnull().sum()
# Out:
# Order ID         0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Order date       0
# Order month      0
# Order year       0
# ship date        0
# ship month       0
# ship year        0
# dtype: int64

# %%
sales['Postal Code']=sales['Postal Code'].astype(int)

# %%
sales
# Out:
#             Order ID       Ship Mode Customer ID     Customer Name    Segment  \
# 0     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 1     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 2     CA-2017-138688    Second Class    DV-13045   Darrin Van Huff  Corporate
# 3     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# 4     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# ...              ...             ...         ...               ...        ...
# 9795  CA-2017-125920  Standard Class    SH-19975     Sally Hughsby  Corporate
# 9796  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9797  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9798  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9799  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
#
# ...

# %%
sales['Sales'].value_counts()
# Out:
# 12.960     55
# 15.552     39
# 19.440     39
# 10.368     35
# 25.920     34
#            ..
# 339.136     1
# 60.048      1
# 5.022       1
# 7.857       1
# 10.384      1
# Name: Sales, Length: 5757, dtype: int64

# %%
sales.nlargest(5,'Postal Code')
# Out:
#             Order ID       Ship Mode Customer ID Customer Name   Segment  \
# 4849  CA-2015-107818  Standard Class    MC-17275    Marc Crier  Consumer
# 4850  CA-2015-107818  Standard Class    MC-17275    Marc Crier  Consumer
# 4851  CA-2015-107818  Standard Class    MC-17275    Marc Crier  Consumer
# 4852  CA-2015-107818  Standard Class    MC-17275    Marc Crier  Consumer
# 7325  US-2018-128447  Standard Class    MC-17845  Michael Chen  Consumer
#
#             Country   City       State  Postal Code Region  ...  \
# 4849  United States  Pasco  Washington        99301   West  ...
# 4850  United States  Pasco  Washington        99301   West  ...
# 4851  United States  Pasco  Washington        99301   West  ...
# 4852  United States  Pasco  Washington        99301   West  ...
# 7325  United States  Pasco  Washington        99301   West  ...
#
#              Category Sub-Category  \
# 4849  Office Supplies          Art
# 4850        Furniture       Chairs
# ...

# %%
sales.nsmallest(5,'Postal Code')
# Out:
#             Order ID       Ship Mode Customer ID Customer Name      Segment  \
# 2415  CA-2016-146087  Standard Class    PP-18955    Paul Prost  Home Office
# 2028  CA-2016-117961  Standard Class    GP-14740   Guy Phonely    Corporate
# 2029  CA-2016-117961  Standard Class    GP-14740   Guy Phonely    Corporate
# 2030  CA-2016-117961  Standard Class    GP-14740   Guy Phonely    Corporate
# 2031  CA-2016-117961  Standard Class    GP-14740   Guy Phonely    Corporate
#
#             Country        City          State  Postal Code Region  ...  \
# 2415  United States     Holyoke  Massachusetts         1040   East  ...
# 2028  United States  Leominster  Massachusetts         1453   East  ...
# 2029  United States  Leominster  Massachusetts         1453   East  ...
# 2030  United States  Leominster  Massachusetts         1453   East  ...
# 2031  United States  Leominster  Massachusetts         1453   East  ...
#
#              Category Sub-Category  \
# 2415        Furniture    Bookcases
# ...

# %%
pd.cut(sales['Sales'],bins=5).value_counts()
# Out:
# (-22.194, 4528.051]       9773
# (4528.051, 9055.658]        19
# (9055.658, 13583.266]        5
# (13583.266, 18110.873]       2
# (18110.873, 22638.48]        1
# Name: Sales, dtype: int64

# %%
pd.qcut(sales['Sales'],q=5).value_counts()
# Out:
# (13.827, 34.24]       1962
# (89.834, 283.92]      1961
# (0.443, 13.827]       1960
# (283.92, 22638.48]    1959
# (34.24, 89.834]       1958
# Name: Sales, dtype: int64

# %%
sales['Sub-Category'].value_counts()
# Out:
# Binders        1492
# Paper          1338
# Furnishings     931
# Phones          876
# Storage         832
# Art             785
# Accessories     756
# Chairs          607
# Appliances      459
# Labels          357
# Tables          314
# Envelopes       248
# Bookcases       226
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: Sub-Category, dtype: int64

# %%
cat=['Binders','Paper','Phones']
sales[sales['Sub-Category'].isin(cat)]
# Out:
#             Order ID       Ship Mode Customer ID     Customer Name    Segment  \
# 7     CA-2015-115812  Standard Class    BH-11710   Brosina Hoffman   Consumer
# 8     CA-2015-115812  Standard Class    BH-11710   Brosina Hoffman   Consumer
# 11    CA-2015-115812  Standard Class    BH-11710   Brosina Hoffman   Consumer
# 12    CA-2018-114412  Standard Class    AA-10480      Andrew Allen   Consumer
# 13    CA-2017-161389  Standard Class    IM-15070      Irene Maddox   Consumer
# ...              ...             ...         ...               ...        ...
# 9793  CA-2015-127166    Second Class    KH-16360  Katherine Hughes   Consumer
# 9794  CA-2015-127166    Second Class    KH-16360  Katherine Hughes   Consumer
# 9795  CA-2017-125920  Standard Class    SH-19975     Sally Hughsby  Corporate
# 9797  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9798  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
#
# ...

# %%
sales
# Out:
#             Order ID       Ship Mode Customer ID     Customer Name    Segment  \
# 0     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 1     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 2     CA-2017-138688    Second Class    DV-13045   Darrin Van Huff  Corporate
# 3     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# 4     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# ...              ...             ...         ...               ...        ...
# 9795  CA-2017-125920  Standard Class    SH-19975     Sally Hughsby  Corporate
# 9796  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9797  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9798  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9799  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
#
# ...

# %%
sales.boxplot()
# Out:
# <AxesSubplot:>

# %%
sale1=sales[sales["Sales"]<93]

# %%
sale1.boxplot('Sales')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='Ship Mode',y='Sales',data=sales)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
sns.barplot('Category','Sales',data=sales)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
sns.barplot('Ship Mode','Postal Code',data=sales)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ship Mode', ylabel='Postal Code'>

# %%
plt.figure(figsize=(15,5))
sns.barplot('Category','Sales',data=sales,hue='Ship Mode',color='g')
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='Sales',y='Category',data=sales,orient='h',palette='winter')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Category'>

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Category',data=sales)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize=(22,8))
sns.countplot('Sub-Category',data=sales,hue='Category')
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot('Ship Mode',data=sales,hue='Category')
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.set_context('poster',font_scale=(0.9))
plt.style.use('seaborn')
plt.xticks(rotation=80)
sns.scatterplot('Ship Mode','Sales',data=sales)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
sns.set_context('poster',font_scale=(0.9))
plt.xticks(rotation=90)
sns.barplot('State','Sales',data=sales)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
plt.figure(figsize=(25,8))
sns.set_context('poster',font_scale=(0.9))
plt.xticks(rotation=90)
sns.barplot('Region','Sales',data=sales,color='c')
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=(90))
sns.set_context('poster',font_scale=(0.9))
sns.violinplot('State','Sales',data=sales)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
sns.stripplot('Ship Mode','Sales',data=sales)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
plt.figure(figsize=(25,8))
sales.plot(kind='scatter',x='Ship Mode',y='Sales')
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
sales.plot(kind='pie',y='Sales',autopct='%.2f')

# %% [markdown]
# # Groupby

# %%
s1=sales.groupby('Ship Mode').mean()

# %%
s1
# Out:
#                  Postal Code       Sales
# Ship Mode
# First Class     54937.705530  230.228020
# Same Day        57459.968401  232.749143
# Second Class    55621.257098  236.547939
# Standard Class  55082.921318  228.849856

# %%
s1.plot(y='Sales',marker='*',c='m',grid=True)
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %%
plt.figure(figsize=(25,8))
s1.plot(kind='bar',y='Sales')
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %%
plt.figure(figsize=(20,8))
s1.plot(kind='pie',y='Sales',autopct='%.2f',legend=False)
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
s1.plot(kind='barh',y='Sales')
# Out:
# <AxesSubplot:ylabel='Ship Mode'>

# %%
s1.plot(kind='hist',y='Sales')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot(s1['Sales'])
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.displot(s1['Sales'],bins=20)

# %%
s2=sales.groupby('Segment').mean()

# %%
s2
# Out:
#                   Row ID   Postal Code       Sales
# Segment
# Consumer     4840.442462  55651.213501  225.065777
# Corporate    5025.899424  54739.385685  233.150720
# Home Office  4863.872852  55071.782235  243.403309

# %%
s2.plot(y='Sales',marker='*',color='c',grid=True)
# Out:
# <AxesSubplot:xlabel='Segment'>

# %%
plt.figure(figsize=(15,8))
s2.plot(kind='pie',y='Sales',autopct='%.2f',legend=False)
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
s2.plot(kind='bar',y='Sales')
# Out:
# <AxesSubplot:xlabel='Segment'>

# %%
sns.displot(s2['Sales'],bins=30,color='m')

# %%
sns.distplot(s2['Sales'])
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
s3=sales.groupby('Region').mean()

# %%
s3
# Out:
#               Row ID   Postal Code       Sales
# Region
# Central  4932.282828  65472.155907  216.357889
# East     4829.551167  17629.076424  240.401697
# South    5003.707760  34491.736546  243.524067
# West     4887.855732  91710.064013  226.184613

# %%
s3.plot(kind='bar',y='Sales')
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
s3.plot(kind='pie',y='Sales',autopct='%.2f',legend=False)
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
s3.plot(y='Sales',marker='*',c='g')
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
sns.displot(s3['Sales'],bins=30)

# %%
sns.distplot(s3['Sales'])
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
s4=sales.groupby('Category').mean()

# %%
s4
# Out:
#                       Row ID   Postal Code       Sales
# Category
# Furniture        4941.283927  55653.970617  350.653790
# Office Supplies  4882.833305  55032.192953  119.381001
# Technology       4911.334804  55623.135359  456.401474

# %%
s4.plot(y='Sales',marker='*',c='r')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
s4.plot(kind='bar',y='Sales')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
s4.plot(kind='pie',y='Sales',autopct='%.2f',legend=False)
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
sns.barplot(x='Order month',y='Sales',data=sales)
# Out:
# <AxesSubplot:xlabel='Order month', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Order date',y='Sales',data=sales)
# Out:
# <AxesSubplot:xlabel='Order date', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
sns.countplot('Order date',data=sales)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Order date', ylabel='count'>

# %%
sns.countplot(x='Order month',data=sales)
# Out:
# <AxesSubplot:xlabel='Order month', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x='Order month',y='Sales',data=sales,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Order month', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Order month',y='Sales',hue='Ship Mode',data=sales)
# Out:
# <AxesSubplot:xlabel='Order month', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
sns.stripplot(x='Order month',y='Sales',data=sales,split=True)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Order month', ylabel='Sales'>

# %%
plt.figure(figsize=(25,9))
sns.set_context('poster',font_scale=(0.5))
sns.factorplot(x='Order date',y='Sales',data=sales,kind='bar')
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.heatmap(sales.corr(),cmap='rainbow',annot=True)
# Out:
# <AxesSubplot:>

# %%
s1=sales.pivot_table(index='Ship Mode',columns='Region',values='Sales')

# %%
s1
# Out:
# Region             Central        East       South        West
# Ship Mode
# First Class     198.826362  234.971687  211.404810  252.529291
# Same Day        170.389169  281.275740  253.218952  222.838689
# Second Class    218.357301  220.937155  287.490882  236.068426
# Standard Class  223.153507  244.303238  235.546799  215.992495

# %%
s1=sales.pivot_table(index='Ship Mode',columns='Region',values='Sales')
sns.heatmap(s1,linewidth=3,linecolor='k',cmap='rainbow',annot=True)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Ship Mode'>

# %%
s2=sales.pivot_table(index='Segment',columns='Category',values='Sales')

# %%
s2
# Out:
# Category      Furniture  Office Supplies  Technology
# Segment
# Consumer     354.708379       116.976760  428.431266
# Corporate    350.830735       125.704170  450.261692
# Home Office  337.928896       115.691831  544.484690

# %%
s2=sales.pivot_table(index='Segment',columns='Category',values='Sales')
sns.heatmap(s2,linewidth=3,linecolor='k',cmap='rainbow',annot=True)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Segment'>

# %%
sales['Product Name'].value_counts()
# Out:
# Staple envelope                                                        47
# Staples                                                                46
# Easy-staple paper                                                      44
# Avery Non-Stick Binders                                                20
# Staples in misc. colors                                                18
#                                                                        ..
# Xiaomi Mi3                                                              1
# Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream     1
# Socket Bluetooth Cordless Hand Scanner (CHS)                            1
# Logitech Illuminated Ultrathin Keyboard with Backlighting               1
# LG G2                                                                   1
# Name: Product Name, Length: 1849, dtype: int64

# %% [markdown]
# # Staples

# %%
s3=['Staples']
s1=sales[sales['Product Name'].isin(s3)]

# %%
s1
# Out:
#             Order ID       Ship Mode Customer ID     Customer Name  \
# 132   US-2018-164147     First Class    DW-13585    Dorothy Wardle
# 342   CA-2015-122336    Second Class    JD-15895  Jonathan Doherty
# 525   CA-2016-158792  Standard Class    BD-11605      Brian Dahlen
# 646   CA-2017-103947  Standard Class    BB-10990   Barry Blumstein
# 1108  US-2017-110156  Standard Class    EH-13945     Eric Hoffmann
# 1147  CA-2016-112452        Same Day    NC-18340       Nat Carroll
# 1485  CA-2015-119032  Standard Class    MS-17770  Maxwell Schwartz
# 1642  US-2015-134712  Standard Class    BS-11380      Bill Stewart
# 1703  CA-2015-139857  Standard Class    CD-12790   Cynthia Delaney
# 1886  CA-2015-140165     First Class    EH-14005   Erica Hernandez
# 2059  CA-2015-106439  Standard Class    GG-14650      Greg Guthrie
# 2144  CA-2017-155481  Standard Class    DK-13225         Dean Katz
# 2387  CA-2016-145065     First Class    DK-13375       Dennis Kane
# ...

# %%
plt.figure(figsize=(20,5))
sns.barplot('Order date','Sales',data=s1)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Order date', ylabel='Sales'>

# %%
sns.barplot('Order year','Sales',data=s1,)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Order year', ylabel='Sales'>

# %%
plt.figure(figsize=(20,8))
sns.barplot('Order month','Sales',data=s1,hue='Ship Mode',palette='rainbow')
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Order month', ylabel='Sales'>

# %%
plt.figure(figsize=(12,5))
sns.barplot('Ship Mode','Sales',data=s1)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.barplot('Customer Name','Sales',data=s1)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer Name', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.barplot('Customer ID','Sales',data=s1)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer ID', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.barplot(x='ship date',y='Sales',data=s1)
# Out:
# <AxesSubplot:xlabel='ship date', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.stripplot(x='Ship Mode',y='Sales',data=s1)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Order year',y='Sales',data=s1)
# Out:
# <AxesSubplot:xlabel='Order year', ylabel='Sales'>

# %%
sales['Product Name'].value_counts()
# Out:
# Staple envelope                                                        47
# Staples                                                                46
# Easy-staple paper                                                      44
# Avery Non-Stick Binders                                                20
# Staples in misc. colors                                                18
#                                                                        ..
# Xiaomi Mi3                                                              1
# Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream     1
# Socket Bluetooth Cordless Hand Scanner (CHS)                            1
# Logitech Illuminated Ultrathin Keyboard with Backlighting               1
# LG G2                                                                   1
# Name: Product Name, Length: 1849, dtype: int64

# %% [markdown]
# # Staple envelope Easy-staple paper

# %%
sale=['Staple envelope','Easy-staple paper']
s4=sales[sales['Product Name'].isin(sale)]

# %%
s4
# Out:
#             Order ID       Ship Mode Customer ID     Customer Name  \
# 34    CA-2018-107727    Second Class    MA-17560      Matt Abelman
# 162   CA-2017-154508  Standard Class    RD-19900       Ruben Dartt
# 283   CA-2016-130883  Standard Class    TB-21520   Tracy Blumstein
# 347   CA-2018-134306  Standard Class    TD-20995     Tamara Dahlen
# 458   US-2017-157945  Standard Class    NF-18385  Natalie Fritzler
# ...              ...             ...         ...               ...
# 9400  CA-2016-167696  Standard Class    BD-11500   Bradley Drucker
# 9418  CA-2015-148285  Standard Class    RD-19810  Ross DeVincentis
# 9498  CA-2018-118213     First Class    AB-10060   Adam Bellavance
# 9530  CA-2018-111759  Standard Class    MR-17545      Mathew Reese
# 9791  CA-2015-127166    Second Class    KH-16360  Katherine Hughes
#
#           Segment        Country          City           State  Postal Code  \
# 34    Home Office  United States       Houston           Texas        77095
# ...

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Ship Mode',y='Sales',data=s4)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Segment',y='Sales',hue='Sub-Category',data=s4)
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %%
sns.countplot(x='Sub-Category',data=s4)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Region',y='Sales',data=sales)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Order date',y='Sales',data=s4)
# Out:
# <AxesSubplot:xlabel='Order date', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x='Order month',y='Sales',data=s4)
# Out:
# <AxesSubplot:xlabel='Order month', ylabel='Sales'>

# %%
plt.figure(figsize=(21,9))
plt.xticks(rotation=90)
sns.barplot(x='State',y='Sales',data=s4,hue='Ship Mode')
# Out:
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.set_context('poster',font_scale=(0.8))
sns.barplot(x='City',y='Sales',data=s4)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Sales'>

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.countplot('City',data=s4)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
s4
# Out:
#             Order ID       Ship Mode Customer ID     Customer Name  \
# 34    CA-2018-107727    Second Class    MA-17560      Matt Abelman
# 162   CA-2017-154508  Standard Class    RD-19900       Ruben Dartt
# 283   CA-2016-130883  Standard Class    TB-21520   Tracy Blumstein
# 347   CA-2018-134306  Standard Class    TD-20995     Tamara Dahlen
# 458   US-2017-157945  Standard Class    NF-18385  Natalie Fritzler
# ...              ...             ...         ...               ...
# 9400  CA-2016-167696  Standard Class    BD-11500   Bradley Drucker
# 9418  CA-2015-148285  Standard Class    RD-19810  Ross DeVincentis
# 9498  CA-2018-118213     First Class    AB-10060   Adam Bellavance
# 9530  CA-2018-111759  Standard Class    MR-17545      Mathew Reese
# 9791  CA-2015-127166    Second Class    KH-16360  Katherine Hughes
#
#           Segment        Country          City           State  Postal Code  \
# 34    Home Office  United States       Houston           Texas        77095
# ...
